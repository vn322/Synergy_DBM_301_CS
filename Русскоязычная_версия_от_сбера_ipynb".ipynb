# %% [markdown]
# <a href="https://colab.research.google.com/github/vn322/Synergy_DBM_301_CS/blob/main/%D0%A0%D1%83%D1%81%D1%81%D0%BA%D0%BE%D1%8F%D0%B7%D1%8B%D1%87%D0%BD%D0%B0%D1%8F_%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%8F_%D0%BE%D1%82_%D1%81%D0%B1%D0%B5%D1%80%D0%B0_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers==4.10.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 25.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 59.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 KB 34.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895259 sha256=43ee3a829f8b28756aeb1a19af8151a0b1f168d0f8ba55dfcbff316b80ca6ed4
#   Stored in directory: /root/.cache/pip/wheels/12/1c/3d/46cf06718d63a32ff798a89594b61e7f345ab6b36d909ce033
# Successfully built sacremoses
# ...

# %%
import torch
import numpy as np
import transformers
from tqdm import tqdm
from torch.utils.data import Dataset, DataLoader
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# %%
# !wget https://files.sberdisk.ru/s/NzeBqYE84TAQDiS/download -O model.zip
# !unzip model.zip -d mgptxl
# model_name = "./mgptxl"
model_name = "sberbank-ai/mGPT"

# %%
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)
# Out:
# Downloading:   0%|          | 0.00/1.89M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.20M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/725 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.45G [00:00<?, ?B/s]

# %%
texts = [
    "Чтобы получить диплом  в университете Синергия нужно ",
]

# %%
model.cuda()
model.eval()
transformers.set_seed(1337)
for text in texts:
    input_ids = tokenizer.encode(text, return_tensors="pt").cuda()
    out = model.generate(
        input_ids, 
        min_length=100,
        max_length=1000,
        eos_token_id=5, 
        pad_token=1,
        do_sample=True,
        top_k=0,
        top_p=0.9,
        no_repeat_ngram_size=4)
    generated_text = list(map(tokenizer.decode, out))[0]
    print('---')
    print(generated_text)
# Out:
# Setting `pad_token_id` to `eos_token_id`:5 for open-end generation.
# ---
# Чтобы получить диплом  в университете Синергия нужно  пройти следующие этапы. Для этого есть достаточно популярные сайты, которые помогут вам. Однако, если вы подумываете о своем будущем за счет желающих зайти на курсы по химии, то возможно у вас возникнет вопрос, как получить знание химии в онлайн. И, несмотря на то, что в действительности это очень просто, нельзя сказать, что что на самом деле то, что вы хотите усвоить. Вероятность того, что у вас что-то получится, просто огромна, ведь найти нужную информацию в интернете очень просто. Но, как быть тем, кто решит сделать это с помощью сети?
# Сайт, посвященный химии, является отличной площадкой для поиска информации. Около 50 таких сайтов есть на нашем портале, а не только в его бумажном виде. В основе его находится география, на которой представлены ссылки на лекции, которые вы можете найти в любом вузовском учебном центре.
# ...
