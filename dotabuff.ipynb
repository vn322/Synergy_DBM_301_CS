# %% [markdown]
# <a href="https://colab.research.google.com/github/vn322/Synergy_DBM_301_CS/blob/main/dotabuff.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Скраппинг таблиц**

# %%
pip install html-table-parser-python3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Library for opening url and creating
# requests
import urllib.request

# pretty-print python data structures
from pprint import pprint

# for parsing all the tables present
# on the website
from html_table_parser.parser import HTMLTableParser

# for converting the parsed data in a
# pandas dataframe
import pandas as pd


# Opens a website and read its
# binary contents (HTTP Response Body)
def url_get_contents(url):

	# Opens a website and read its
	# binary contents (HTTP Response Body)

	#making request to the website
	req = urllib.request.Request(url=url, headers = {'User-agent': 'your bot 0.1'})
	f = urllib.request.urlopen(req)

	#reading contents of the website
	return f.read()

# defining the html contents of a URL.
xhtml = url_get_contents('https://www.dotabuff.com/matches').decode('utf-8')

# Defining the HTMLTableParser object
p = HTMLTableParser()

# feeding the html contents in the
# HTMLTableParser object
p.feed(xhtml)

# Now finally obtaining the data of
# the table required
print('===============================================')
pprint(p.tables[0])

# converting the parsed data to
# dataframe
print('================================================')
print("\n\nPANDAS DATAFRAME\n")
print('================================================')
x = pd.DataFrame(p.tables[0])
print(x)
# Out:
# ...
# [['Match ID', 'Game Mode', 'Result', 'Duration', 'Radiant Team', 'Dire Team'],
#  ['7077058106 2023-03-25',
#   'All Random Normal Matchmaking',
#   'Dire Victory Russia',
#   '35:48',
#   '',
#   ''],
#  ['7077070749 2023-03-25',
#   'Single Draft Normal Matchmaking',
#   'Radiant Victory Europe',
#   '28:26',
#   '',
#   ''],
#  ['7077046746 2023-03-25',
#   'Single Draft Normal Matchmaking',
#   'Radiant Victory Russia',
#   '41:00',
#   '',
#   ''],
#  ['7077049829 2023-03-25',
#   'All Pick Ranked Matchmaking',
#   'Radiant Victory SE Asia',
#   '39:24',
#   '',
#   ''],
#  ['7077065801 2023-03-25',
#   'Single Draft Normal Matchmaking',
#   'Radiant Victory Europe',
#   '30:57',
#   '',
#   ''],
#  ['7077038940 2023-03-25',
#   'All Pick Normal Matchmaking',
#   'Dire Victory Russia',
#   '44:56',
#   '',
#   ''],
#  ['7077046634 2023-03-25',
#   'All Pick Ranked Matchmaking',
#   'Radiant Victory China',
#   '40:53',
#   '',
#   ''],
#  ['7077029867 2023-03-25',
# ...

# %%
x
# Out:
#                         0                                1  \
# 0                Match ID                        Game Mode
# 1   7077058106 2023-03-25    All Random Normal Matchmaking
# 2   7077070749 2023-03-25  Single Draft Normal Matchmaking
# 3   7077046746 2023-03-25  Single Draft Normal Matchmaking
# 4   7077049829 2023-03-25      All Pick Ranked Matchmaking
# 5   7077065801 2023-03-25  Single Draft Normal Matchmaking
# 6   7077038940 2023-03-25      All Pick Normal Matchmaking
# 7   7077046634 2023-03-25      All Pick Ranked Matchmaking
# 8   7077029867 2023-03-25      All Pick Ranked Matchmaking
# 9   7077045928 2023-03-25  Single Draft Normal Matchmaking
# 10  7077069114 2023-03-25      All Pick Normal Matchmaking
# 11  7077023393 2023-03-25      All Pick Normal Matchmaking
# 12  7076993540 2023-03-25      All Pick Normal Matchmaking
# 13  7077069374 2023-03-25      All Pick Normal Matchmaking
# 14  7077039690 2023-03-25      All Pick Ranked Matchmaking
# ...

# %%
x.to_excel('output1.xlsx')

# %%
x.to_csv('out.csv')
