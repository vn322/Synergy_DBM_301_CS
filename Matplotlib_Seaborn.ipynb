# %% [markdown]
# <a href="https://colab.research.google.com/github/vn322/Synergy_DBM_301_CS/blob/main/Matplotlib_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Общие сведения об элементах графиков

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Простейшие объекты и форматирование

# %%
# Создание объекта Figure
fig = plt.figure()
# тип объекта Figure
print (type(fig))
# scatter - метод для нанесения маркера в точке (1.0, 1.0)
plt.scatter(1.0, 1.0)
print (fig.axes)
# После нанесения графического элемента в виде маркера, список текущих областей состоит из одной области
plt.show()
# Out:
# <class 'matplotlib.figure.Figure'>
# ...

# %% [markdown]
# В настройках Matplotlib (rcParams) существует такой параметр как fonts, то есть шрифты. Всего существует 5 наборов шрифтов:
#
# cursive;
#
# fantasy;
#
# monospace;
#
# sans-serif;
#
# serif.
#
# Один из этих пяти наборов является текущим. За это отвечает параметр font.family. Каждый набор может состоять из одного или более шрифтов. Данная настройка определяет шрифт для всех подписей и текста на рисунке. Если конкретную подпись необходимо сделать другим шрифтом, можно указать шрифт из текущего стиля прямо в команде, передав в качестве соответствующего параметра словарь

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

mpl.rcParams['font.fantasy'] = 'Arial', 'Times New Roman', 'Tahoma', 'Comic Sans MS', 'Courier'
mpl.rcParams['font.family'] = 'fantasy'
# Текущий стиль-семейство шрифтов
cfam = mpl.rcParams.get('font.family')[0]
print('cfam %s' % cfam)
cfont = mpl.rcParams.get('font.fantasy')[0]
# Первый шрифт в текущем семействе
print(mpl.rcParams.get('font.%s' % cfam))
N = 100
x = np.arange(N)
# Задаём выборку из Гамма-распредления с параметрами формы=1. и масштаба=3.0
y = np.random.gamma(1.0, 3.0, N)
fig = plt.figure()
cc = plt.hist(y)
text_style = ['italic', 'oblique', 'normal']
font_weights = ['bold', 'light', 'normal']
for i, ts in enumerate(text_style):
 plt.text(6, 20-5*i, '%s text style' % ts, {'fontname':'Courier'}, style=ts, fontsize=14)
 plt.text(6, 35-4*i, '%s & %s text style' % (ts, font_weights[i]), {'fontname':'Courier'},
 style=ts, fontweight=font_weights[i], fontsize=12)

plt.title('Title has %s font' % cfont, fontweight='normal', color='k', fontsize=16)
plt.xlabel('Bold weight', {'fontname':'Times New Roman'}, fontweight='bold', fontsize=16)
plt.ylabel('Light weight', {'fontname':'Times New Roman'}, fontweight='light', fontsize=14)
plt.grid(True)
plt.show()
# Out:
# cfam fantasy
# ['Arial', 'Times New Roman', 'Tahoma', 'Comic Sans MS', 'Courier']

# %% [markdown]
# # Кастомизация графиков

# %% [markdown]
# $y = x ^2$

# %%
x = np.linspace(-10, 10, 20)
y = x**2;
plt.plot(x, y, color='red', label='Линия 1');
plt.grid() # сетка
plt.xlabel('ось x', fontsize=14) 
# добавляем подпись к оси абцисс "ось х"
plt.ylabel('ось y', fontsize=14) 
# добавляем подпись к оси ординат "ось y"
plt.title(r'График функций $y = x ^2$', fontsize=16, y=1.05); 
# добавляем заголовок к графику "График функции y=x^2
plt.text(-2., 10., 'Минимум',fontsize=12); 
# добавляем подпись к графику в точке (-2.5, 10)

# %%
plt.plot(x, y, color='red', label='Линия 1');
plt.grid() # сетка
plt.xlabel('ось x', fontsize=14) 
# добавляем подпись к оси абцисс "ось х"
plt.ylabel('ось y', fontsize=14) 
# добавляем подпись к оси ординат "ось y"
plt.title(r'График функций $y = x ^2$', fontsize=16, y=1.05); 
# добавляем заголовок к графику "График функции y=x^2
plt.annotate("Минимум", xy=(0.,0.), xytext=(-1.9,70.),fontsize=12, 
             arrowprops = dict(arrowstyle = '->',color = 'red'))
# Out:
# Text(-1.9, 70.0, 'Минимум')

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
a = 1.
x = np.arange(0., 2*np.pi, 0.1)
xz = a*(np.sin(1/2*x) - np.cos(3*x))
fig = plt.figure()
plt.plot(xz)
plt.text(7., 2., 'у = sin(x/2)-cos(3x)', fontsize=14,
 # выравнивание по вертикали и по горизонтали
 horizontalalignment='center', verticalalignment='center',
 bbox=dict(facecolor='pink', alpha=1.0))
plt.grid()
plt.show()

# %% [markdown]
# # Пример визуализации данных

# %% [markdown]
# Определим наш тренировочный набор данных, где будут наблюдения за 8 персонажами с различными показателями защиты, атаки и в качестве зависимой переменной возьмём количество побед.

# %%
data = {
    'Защита': [8, 9, 10, 11, 10, 12, 14, 16, 15, 15, 17, 16, 17, 18],
    'Атака': [20, 20, 25, 22, 24, 26, 30, 32, 37, 40, 35, 30, 29, 27],
    'Победы': [50, 45, 50, 47, 51, 48, 52, 54, 50, 60, 62, 63, 48, 55]
}
df = pd.DataFrame(data)
df
# Out:
#     Защита  Атака  Победы
# 0        8     20      50
# 1        9     20      45
# 2       10     25      50
# 3       11     22      47
# 4       10     24      51
# 5       12     26      48
# 6       14     30      52
# 7       16     32      54
# 8       15     37      50
# 9       15     40      60
# 10      17     35      62
# 11      16     30      63
# 12      17     29      48
# 13      18     27      55

# %% [markdown]
# Построить простые графики можно и в  библиотеке pandas

# %%
df[['Защита', 'Атака']].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Построив его в Matplotlib получаем большую выразительность и повышаем объяснительную способность.

# %%
graph1 = plt.plot(df['Атака'],color='red', marker='o', 
                  linestyle='--', label='Атака')
graph2 = plt.plot(df['Защита'],color='green', 
                  marker='v',linestyle=':', label='Защита')

text1 = plt.text(5, 35, 'Атака')
text2 = plt.text(5, 13, 'Защита')
grid1 = plt.grid(True) # линии вспомогательной сетки
plt.show()

# %% [markdown]
# здесь приведены различные элементы кастомизации
#
# '-'       solid line style
# '--'      dashed line style
# '-.'      dash-dot line style
# ':'       dotted line style
# '.'       point marker
# ','       pixel marker
# 'o'       circle marker
# 'v'       triangle_down marker
# '^'       triangle_up marker
# '<'       triangle_left marker
# '>'       triangle_right marker
# '1'       tri_down marker
# '2'       tri_up marker
# '3'       tri_left marker
# '4'       tri_right marker
# 's'       square marker
# 'p'       pentagon marker
# '*'       star marker
# 'h'       hexagon1 marker
# 'H'       hexagon2 marker
# '+'       plus marker
# 'x'       x marker
# 'D'       diamond marker
# 'd'       thin_diamond marker
# '|'       vline marker
# '_'       hline marker

# %% [markdown]
# Можно так же строить графики внутри графиков.

# %%
# Python program to show pyplot module
import matplotlib.pyplot as plt
from matplotlib.figure import Figure

# Creating a new figure 
fig = plt.figure(figsize =(7, 6))

# Creating first axes for the figure
ax1 = fig.add_axes([0.5, 0.3, 0.8, 0.8])

# Creating second axes for the figure
ax2 = fig.add_axes([0.55, 0.8, 0.3, 0.2])

# Adding the data to be plotted
ax1.plot(df[['Победы']])
ax2.plot(df[['Защита', 'Атака']])
plt.show()

# %% [markdown]
# Так же возможно создать панно из графиков любой конфигурации

# %%
# Creating figure object
plt.figure()
fig = plt.figure(figsize =(7, 5))

# addind first subplot
plt.subplot(121)
plt.plot(df['Защита'])
plt.legend(["Защита"])

# addding second subplot
plt.subplot(122)
plt.plot(df[['Атака']])

plt.legend(["Атака"])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
fg = plt.figure(figsize=(9, 4), constrained_layout=True)
gs = fg.add_gridspec(2, 2)

fig_ax_1 = fg.add_subplot(gs[0, :2])
plt.plot(df[['Победы']], color='red')
plt.legend(["Победы"])

fig_ax_2 = fg.add_subplot(gs[1, 0])
plt.plot(df[['Атака']])
plt.legend(["Атака"])

fig_ax_3 = fg.add_subplot(gs[1, 1])
plt.plot(df['Защита'], color='green')
plt.legend(["Защита"])

# %%
fig, ax = plt.subplots()
width = 1.1
ax.bar(df['Защита'], df['Победы'], 
       width=width, label='Защита')
ax.bar(df['Атака'] , df['Победы'], 
       width=width, label='Атака')
ax.legend(loc='upper left')

plt.show()

# %%
plt.hist(df['Победы'], bins=15, color='b', edgecolor='r',
         linestyle='--', alpha=0.5)
 
# Adding title to the plot
plt.title("Частотное распр-е")
 
# Adding label on the y-axis
plt.ylabel('Частота')
 
# Adding label on the x-axis
plt.xlabel('Кол-во')
 
plt.show()

# %% [markdown]
# # Сложные визуализации

# %% [markdown]
# Однако большей выразительности можно достичь в библиотеке Seaborn предназначенной для создания статистических графиков на Python. Она построена на основе Matplotlib и так же тесно интегрируется со структурами данных Pandas.

# %% [markdown]
# distplot одновременно показывает гистограмму и график плотности распределения.

# %%
sns.distplot(df.Защита)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Для визуализации регрессионных моделей в Seaborn есть две функции: regplot() и lmplot(). Первая строит графики на уровне области Axes и может принимать в качестве данных любые форматы последовательности чисел (списки и кортежи Python, массивы NumPy, серии Pandas):

# %%
plt.subplots(figsize=(10, 7))
sns.regplot(x = df['Защита'],
            y = df['Победы'], x_estimator=np.mean)
# Out:
# <AxesSubplot:xlabel='Защита', ylabel='Победы'>

# %% [markdown]
# С помощью параметра robust можно установить устойчивую к выбросам модель регрессии

# %%
plt.subplots(figsize=(10, 7))
sns.set_style('whitegrid')
sns.regplot(x = df['Атака'],
            y = df['Победы'], 
            robust=True,
            x_estimator=np.mean)

# %% [markdown]
# Если в данных наблюдается полиномиальная тенденция, то построить соответствующую линию регрессии можно с помощью параметра order

# %%
plt.subplots(figsize=(10, 7))
sns.set_style('whitegrid')
sns.regplot(x = df['Атака'],
            y = df['Победы'],
            order=2)
# Out:
# <AxesSubplot:xlabel='Атака', ylabel='Победы'>

# %% [markdown]
# Еще одна возможность, заключается в построении непараметрической регрессии, которая позволяет выявлять более сложные регрессионные зависимости

# %%
fig = plt.figure()

ax_1 = fig.add_subplot(1, 2, 1)
ax_2 = fig.add_subplot(1, 2, 2)

sns.regplot(x='Атака', 
           y='Победы',
           data=df,
           lowess=False,
           scatter_kws={"color": "0.4"},
           line_kws={"color": "red"},
           ax=ax_1);

sns.regplot(x='Атака', 
           y='Победы',
           data=df,
           lowess=True,
           scatter_kws={"color": "0.4"},
           line_kws={"color": "red"},
           ax=ax_2);

ax_1.set_title('Линейная регрессия',
               fontsize=15)
ax_2.set_title('Непараметрическая регрессия',
               fontsize=15)

fig.set_figwidth(14)
fig.set_figheight(7)

plt.show()

# %% [markdown]
# Даже очень сложные графики в Seaborn имеют высокую объяснительную способность и являются ценным инструментом в анализе данных.

# %% [markdown]
# Функция jointplot() показывает совместное распределение по двум переменным. Она имеет параметр kind который может принимать следующие значения:
#
# “scatter”
#
# “reg”
#
# “resid”
#
# “kde”
#
# “hex”

# %%
sns.jointplot(x='Защита',
              y='Победы',
              data=df,
              kind='reg')

# %% [markdown]
# Тепловая карта — графическое представление данных, где индивидуальные значения в таблице отображаются при помощи цвета. Достаточно эффективно этот вид графика используется для представления результатов корреляционного анализа, особенно когда сравнивается большое количество признаков и представление их в виде таблицы не является достаточно эффективным решением.

# %%
fig, ax = plt.subplots(figsize=(7, 6))
sns.heatmap(df.corr(), annot = True, cmap= 'Pastel2')
# Out:
# <AxesSubplot:>

# %%
lol = pd.read_csv('https://raw.githubusercontent.com/vn322/Sport-University/main/esport/high_diamond_ranked_10min.csv')

# %%
lol.to_excel("output.xlsx")

# %%
pd.read_excel("output.xlsx", index_col=0)
# Out:
#           gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  \
# 0     4519157822         0               28                   2
# 1     4523371949         0               12                   1
# 2     4521474530         0               15                   0
# 3     4524384067         0               43                   1
# 4     4436033771         0               75                   4
# ...          ...       ...              ...                 ...
# 9874  4527873286         1               17                   2
# 9875  4527797466         1               54                   0
# 9876  4527713716         0               23                   1
# 9877  4527628313         0               14                   4
# 9878  4523772935         1               18                   0
#
#       blueFirstBlood  blueKills  blueDeaths  blueAssists  blueEliteMonsters  \
# 0                  1          9           6           11                  0
# ...

# %%
fig, ax = plt.subplots(figsize=(14, 14))
sns.heatmap(lol.corr(),  cmap= 'Pastel2')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Вернувшись к библиотеке Matplotlib стоит упомянуть графики Box plot и Violin plot, которые очень хорошо подходят для сравнения распределения признаков.

# %% [markdown]
# Другое название boxplot — ящик с усами или диаграмма размаха. Он был разработан Джоном Тьюки в 1970-х годах.
#
# Такой вид диаграммы в удобной форме показывает медиану (или, если нужно, среднее), нижний и верхний квартили, минимальное и максимальное значение выборки и выбросы. Несколько таких ящиков можно нарисовать бок о бок, чтобы визуально сравнивать одно распределение с другим; их можно располагать как горизонтально, так и вертикально. Расстояния между различными частями ящика позволяют определить степень разброса (дисперсии) и асимметрии данных и выявить выбросы.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(11, 6))

# plot violin plot
axs[0].violinplot(df,
                  showmeans=False,
                  showmedians=True)
axs[0].set_title('Violin plot')

# plot box plot
axs[1].boxplot(df)
axs[1].set_title('Box plot')


plt.show()

# %%
import numpy as np

df['Эффективность'] = np.where(df['Победы']<50, 'Малая','Большая' )

# %%
df['Эффективность']
# Out:
# 0     Большая
# 1       Малая
# 2     Большая
# 3       Малая
# 4     Большая
# 5       Малая
# 6     Большая
# 7     Большая
# 8     Большая
# 9     Большая
# 10    Большая
# 11    Большая
# 12      Малая
# 13    Большая
# Name: Эффективность, dtype: object

# %%
g = sns.catplot(x='Эффективность',
            y='Победы',
            kind='violin',
            bw=0.45,
            palette='Spectral', 
            data=df)
g.fig.set_figwidth(6)
g.fig.set_figheight(7)

# %% [markdown]
# Ступенчатый график как правило используется для отображения динамики показателей по временным промежуткам. Он строится с помощью функции step()
#
#  {‘pre’, ‘post’, ‘mid’}, optional, default ‘pre’
# Определяет место, где будет установлен шаг.
#
# ‘pre’: значение y ставится слева от значения x, т.е. значение $y_i$ определяется для интервала $(x_{i-1}; x_{i})$.
#
# ‘post’: значение y ставится справа от значения x, т.е. значение $y_i$ определяется для интервала $(x_i; x_{i+1})$.
#
# ‘mid’: значение y ставится в середине интервала.

# %%
where_set = ['pre', 'post', 'mid']
fig, axs = plt.subplots(1, 3, figsize=(15, 4))
for i, ax in enumerate(axs):
  ax.step(df['Атака'], "g-o", where=where_set[i])
  ax.grid()

# %% [markdown]
# Так же есть возможность построения трёхмерных графиков и в некоторых случаях они могут быть полезны для обнаружения ранее не явных закономерностей.

# %%
fig = plt.figure()
fig = plt.figure(figsize =(9, 8))

# keeping the projection = 3d
# ctreates the 3d plot
ax = plt.axes(projection = '3d')
ax.plot3D(df['Атака'].to_list(), 
          df['Защита'].to_list(), df['Победы'].to_list())

fig = plt.figure()
fig = plt.figure(figsize =(9, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['Атака'].to_list(), 
          df['Защита'].to_list(), df['Победы'].to_list(), color='r')

# %%
lol.columns
# Out:
# Index(['gameId', 'blueWins', 'blueWardsPlaced', 'blueWardsDestroyed',
#        'blueFirstBlood', 'blueKills', 'blueDeaths', 'blueAssists',
#        'blueEliteMonsters', 'blueDragons', 'blueHeralds',
#        'blueTowersDestroyed', 'blueTotalGold', 'blueAvgLevel',
#        'blueTotalExperience', 'blueTotalMinionsKilled',
#        'blueTotalJungleMinionsKilled', 'blueGoldDiff', 'blueExperienceDiff',
#        'blueCSPerMin', 'blueGoldPerMin', 'redWardsPlaced', 'redWardsDestroyed',
#        'redFirstBlood', 'redKills', 'redDeaths', 'redAssists',
#        'redEliteMonsters', 'redDragons', 'redHeralds', 'redTowersDestroyed',
#        'redTotalGold', 'redAvgLevel', 'redTotalExperience',
#        'redTotalMinionsKilled', 'redTotalJungleMinionsKilled', 'redGoldDiff',
#        'redExperienceDiff', 'redCSPerMin', 'redGoldPerMin'],
#       dtype='object')

# %%
fig = plt.figure()
fig = plt.figure(figsize =(9, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(lol['blueTotalGold'].to_list(), 
          lol['redTotalGold'].to_list(), lol['blueWins'].to_list())

# %% [markdown]
# Но лучшим материалом для размышлений, когда количество переменных не большое, является попарный график всех имеющихся в данных переменных.

# %%
sns.pairplot(lol[['blueKills', 'blueDeaths', 'blueAssists']])

# %%
sns.pairplot(df)

# %% [markdown]
# Плотность распределения по двум переменным даёт нам градиент. Градиент — вектор, своим направлением указывающий направление наибольшего возрастания некоторой величины, значение которой меняется от одной точки пространства к другой (скалярного поля), а по величине (модулю) равный скорости роста этой величины в этом направлении.

# %%
g = sns.PairGrid(df)
g.map_diag(plt.hist)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

# %% [markdown]
# # Задание

# %% [markdown]
# На избранном наборе данных построить 5 визуализаций и с помощью них создать рассказ о закономерностях, связях  обнаруженных в этих данных.
